# %% [markdown]
# # Acquiring the data from the interwebz using worldfootballR
#
# ### This notebook loads data using the worldfootballR package. To understand this package and the code better, I suggest reading the documentation.

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## I am trying to create a dataframe that collates points for every year along with expenditure
#
# Using the package worldfootballR, we will import historical ponts tables and then add them into one big dataframe.
# I am using historical transfer data from transferMarkt.

# %%
# %%R
#
# require('worldfootballR')
# Out:
# R[write to console]: Loading required package: worldfootballR

# %%
# %%R -o league_2023
#
# league_2023 <- try({
# fb_season_team_stats("ENG", "M", 2023, "1st", "league_table")
# })

# %%
# %%R -o league_2022
#
# league_2022 <- try({
# fb_season_team_stats("ENG", "M", 2022, "1st", "league_table")
# })

# %%
# %%R -o league_2021
#
# league_2021 <- try({
# fb_season_team_stats("ENG", "M", 2021, "1st", "league_table")
# })

# %%
# %%R -o league_2020
#
# league_2020 <- try({
# fb_season_team_stats("ENG", "M", 2020, "1st", "league_table")
# })

# %%
# %%R -o league_2019
#
# league_2019 <- try({
# fb_season_team_stats("ENG", "M", 2019, "1st", "league_table")
# })

# %%
# %%R -o league_2018
#
# league_2018 <- try({
# fb_season_team_stats("ENG", "M", 2018, "1st", "league_table")
# })

# %%
# %%R -o league_2017
#
# league_2017 <- try({
# fb_season_team_stats("ENG", "M", 2017, "1st", "league_table")
# })

# %%
# %%R -o league_2016
#
# league_2016 <- try({
# fb_season_team_stats("ENG", "M", 2016, "1st", "league_table")
# })

# %%
# %%R -o league_2015
#
# league_2015 <- try({
# fb_season_team_stats("ENG", "M", 2015, "1st", "league_table")
# })

# %%
# %%R -o league_2014
#
# league_2014 <- try({
# fb_season_team_stats("ENG", "M", 2014, "1st", "league_table")
# })

# %%
# %%R -o league_2013
#
# league_2013 <- try({
# fb_season_team_stats("ENG", "M", 2013, "1st", "league_table")
# })

# %%
# %%R -o league_2012
#
# league_2012 <- try({
# fb_season_team_stats("ENG", "M", 2012, "1st", "league_table")
# })

# %%
# %%R -o league_2011
#
# league_2011 <- try({
# fb_season_team_stats("ENG", "M", 2011, "1st", "league_table")
# })

# %%
# %%R -o league_2010
#
# league_2010 <- try({
# fb_season_team_stats("ENG", "M", 2010, "1st", "league_table")
# })

# %%
# %%R -o league_2009
#
# league_2009 <- try({
# fb_season_team_stats("ENG", "M", 2009, "1st", "league_table")
# })

# %%
# %%R -o league_2008
#
# league_2008 <- try({
# fb_season_team_stats("ENG", "M", 2008, "1st", "league_table")
# })

# %%
# %%R -o league_2007
#
# league_2007 <- try({
# fb_season_team_stats("ENG", "M", 2007, "1st", "league_table")
# })

# %%
# %%R -o league_2006
#
# league_2006 <- try({
# fb_season_team_stats("ENG", "M", 2006, "1st", "league_table")
# })

# %%
# %%R -o league_2005
#
# league_2005 <- try({
# fb_season_team_stats("ENG", "M", 2005, "1st", "league_table")
# })

# %%
# %%R -o league_2004
#
# league_2004 <- try({
# fb_season_team_stats("ENG", "M", 2004, "1st", "league_table")
# })

# %%
# %%R -o league_2003
#
# league_2003 <- try({
# fb_season_team_stats("ENG", "M", 2003, "1st", "league_table")
# })

# %%
# %%R -o league_2002
#
# league_2002 <- try({
# fb_season_team_stats("ENG", "M", 2002, "1st", "league_table")
# })

# %%
# %%R -o league_2001
#
# league_2001 <- try({
# fb_season_team_stats("ENG", "M", 2001, "1st", "league_table")
# })

# %%
# %%R -o league_2000
#
# league_2000 <- try({
# fb_season_team_stats("ENG", "M", 2000, "1st", "league_table")
# })

# %%
# %%R -o league_1999
#
# league_1999 <- try({
# fb_season_team_stats("ENG", "M", 1999, "1st", "league_table")
# })

# %%
# %%R -o league_1998
#
# league_1998 <- try({
# fb_season_team_stats("ENG", "M", 1998, "1st", "league_table")
# })

# %%
# %%R -o league_1997
#
# league_1997 <- try({
# fb_season_team_stats("ENG", "M", 1997, "1st", "league_table")
# })

# %%
# %%R -o league_1996
#
# league_1996 <- try({
# fb_season_team_stats("ENG", "M", 1996, "1st", "league_table")
# })

# %%
# %%R -o league_1995
#
# league_1995 <- try({
# fb_season_team_stats("ENG", "M", 1995, "1st", "league_table")
# })

# %%
# %%R -o league_1994
#
# league_1994 <- try({
# fb_season_team_stats("ENG", "M", 1994, "1st", "league_table")
# })

# %%
# %%R -o league_1993
#
# league_1993 <- try({
# fb_season_team_stats("ENG", "M", 1993, "1st", "league_table")
# })

# %%
# %%R -o league_1992
#
# league_1992 <- try({
# fb_season_team_stats("ENG", "M", 1992, "1st", "league_table")
# })

# %%
#save all the dataframes as one list in python
league_list = [league_2023, league_2022, league_2021, league_2020, league_2019, league_2018, league_2017, league_2016, league_2015, league_2014, league_2013, league_2012, league_2011, league_2010, league_2009, league_2008, league_2007, league_2006, league_2005, league_2004, league_2003, league_2002, league_2001, league_2000, league_1999, league_1998, league_1997, league_1996, league_1995, league_1994, league_1993, league_1992]

# %%
#Loop through league_list and rename each Pts column to the year of the season and save it as a csv
for i in range(len(league_list)):
    league_list[i].rename(columns={'Pts': 'Pts_'+str(2023-i)}, inplace=True)
    league_list[i] = league_list[i][['Squad', 'Pts_'+str(2023-i)]]
    league_list[i].to_csv('data/league_'+str(2023-i)+'.csv', index=False)

# %%
#Keep all the squads in one column and all the points for each season in another column
league_2023 = pd.read_csv('data/league_2023.csv')
league_2022 = pd.read_csv('data/league_2022.csv')
league_2021 = pd.read_csv('data/league_2021.csv')
league_2019 = pd.read_csv('data/league_2019.csv')
league_2020 = pd.read_csv('data/league_2020.csv')
league_2018 = pd.read_csv('data/league_2018.csv')
league_2017 = pd.read_csv('data/league_2017.csv')
league_2016 = pd.read_csv('data/league_2016.csv')
league_2015 = pd.read_csv('data/league_2015.csv')
league_2014 = pd.read_csv('data/league_2014.csv')
league_2013 = pd.read_csv('data/league_2013.csv')
league_2012 = pd.read_csv('data/league_2012.csv')
league_2011 = pd.read_csv('data/league_2011.csv')
league_2010 = pd.read_csv('data/league_2010.csv')
league_2009 = pd.read_csv('data/league_2009.csv')
league_2008 = pd.read_csv('data/league_2008.csv')
league_2007 = pd.read_csv('data/league_2007.csv')
league_2006 = pd.read_csv('data/league_2006.csv')
league_2005 = pd.read_csv('data/league_2005.csv')
league_2004 = pd.read_csv('data/league_2004.csv')
league_2003 = pd.read_csv('data/league_2003.csv')
league_2002 = pd.read_csv('data/league_2002.csv')
league_2001 = pd.read_csv('data/league_2001.csv')
league_2000 = pd.read_csv('data/league_2000.csv')
league_1999 = pd.read_csv('data/league_1999.csv')
league_1998 = pd.read_csv('data/league_1998.csv')
league_1997 = pd.read_csv('data/league_1997.csv')
league_1996 = pd.read_csv('data/league_1996.csv')
league_1995 = pd.read_csv('data/league_1995.csv')
league_1994 = pd.read_csv('data/league_1994.csv')
league_1993 = pd.read_csv('data/league_1993.csv')
league_1992 = pd.read_csv('data/league_1992.csv')

# %%
#Merge all the dataframes into one dataframe
league_historical = pd.merge(league_2023, league_2022, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2021, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2020, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2019, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2018, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2017, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2016, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2015, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2014, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2013, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2012, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2011, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2010, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2009, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2008, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2007, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2006, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2005, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2004, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2003, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2002, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2001, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_2000, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1999, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1998, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1997, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1996, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1995, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1994, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1993, on='Squad', how='outer')
league_historical = pd.merge(league_historical, league_1992, on='Squad', how='outer')


#only keep the Pts columns for each season and rename it to the year of the season
league_historical
# Out:
#               Squad  Pts_2023  Pts_2022  Pts_2021  Pts_2020  Pts_2019  \
# 0           Arsenal      81.0      69.0      61.0      56.0      70.0
# 1       Aston Villa      57.0      45.0      55.0      35.0       NaN
# 2       Bournemouth      39.0       NaN       NaN      34.0      45.0
# 3         Brentford      50.0      46.0       NaN       NaN       NaN
# 4          Brighton      55.0      51.0      41.0      41.0      36.0
# 5           Chelsea      43.0      74.0      67.0      66.0      72.0
# 6    Crystal Palace      43.0      48.0      44.0      43.0      49.0
# 7           Everton      32.0      39.0      59.0      49.0      54.0
# 8            Fulham      51.0       NaN      28.0       NaN      26.0
# 9      Leeds United      31.0      38.0      59.0       NaN       NaN
# 10   Leicester City      30.0      52.0      66.0      62.0      52.0
# 11        Liverpool      62.0      92.0      69.0      99.0      97.0
# ...

# %%
#Some cleaning up so that we can merge the dataframes later
league_historical['Squad'] = league_historical['Squad'].str.replace('Utd', 'United')
league_historical['Squad'] = league_historical['Squad'].str.replace('Weds', 'Wednesday')
league_historical['Squad'] = league_historical['Squad'].str.replace('Wolves', 'Wolverhampton Wanderers')
league_historical['Squad'] = league_historical['Squad'].str.replace('QPR', 'Queens Park Rangers')
league_historical['Squad'] = league_historical['Squad'].str.replace('Bolton', 'Bolton Wanderers')
league_historical['Squad'] = league_historical['Squad'].str.replace('Nott\'ham Forest', 'Nottingham Forest')
league_historical['Squad'] = league_historical['Squad'].str.replace('Charlton Ath', 'Charlton Athletic')

# %%
#add a column called 'Total_Pts' that sums up all the points for each team
league_historical['Total_Pts'] = league_historical.sum(axis=1)
league_historical
# Out:
#                       Squad  Pts_2023  Pts_2022  Pts_2021  Pts_2020  Pts_2019  \
# 0                   Arsenal      81.0      69.0      61.0      56.0      70.0
# 1               Aston Villa      57.0      45.0      55.0      35.0       NaN
# 2               Bournemouth      39.0       NaN       NaN      34.0      45.0
# 3                 Brentford      50.0      46.0       NaN       NaN       NaN
# 4                  Brighton      55.0      51.0      41.0      41.0      36.0
# 5                   Chelsea      43.0      74.0      67.0      66.0      72.0
# 6            Crystal Palace      43.0      48.0      44.0      43.0      49.0
# 7                   Everton      32.0      39.0      59.0      49.0      54.0
# 8                    Fulham      51.0       NaN      28.0       NaN      26.0
# 9              Leeds United      31.0      38.0      59.0       NaN       NaN
# 10           Leicester City      30.0      52.0      66.0      62.0      52.0
# ...

# %%
#save league as a csv file
league_historical.to_csv('points.csv', index=False)

# %% [markdown]
# ### Now, I am reading in the fees file which is data scraped from transfermarkt.

# %%
prem_champ_df = pd.read_csv('master.csv')

# %%
#find bolton in the dataframe, not exact match
prem_champ_df[prem_champ_df['club_name'].str.contains('Charlton')]
# Out:
#                 club_name            player_name   age          position  \
# 175953  Charlton Athletic           Chris Powell  28.0         Left-Back
# 175954  Charlton Athletic          Neil Redfearn  33.0  Central Midfield
# 175955  Charlton Athletic             Carl Tiler  28.0       Centre-Back
# 175956  Charlton Athletic            Simon Royce  26.0        Goalkeeper
# 175957  Charlton Athletic             Paul Smith  18.0        Goalkeeper
# ...                   ...                    ...   ...               ...
# 264422  Charlton Athletic  Ashley Maynard-Brewer  20.0        Goalkeeper
# 264423  Charlton Athletic             Joe Ledley  33.0  Central Midfield
# 264424  Charlton Athletic        Conor Gallagher  19.0  Central Midfield
# 264425  Charlton Athletic          Jonathan Leko  20.0      Right Winger
# 264426  Charlton Athletic            Beram Kayal  31.0  Central Midfield
#
#          club_involved_name                      fee transfer_movement  \
# ...

# %%
prem_champ_df = prem_champ_df[prem_champ_df['club_name'].isin(['Chelsea FC', 'Manchester United', 'Manchester City', 'Liverpool FC', 'Norwich City', 'Huddersfield Town', 'Blackpool FC', 'Wimbledon FC', 'Ipswich Town',
 'Arsenal FC', 'Tottenham Hotspur', 'Leicester City', 'West Ham United', 'Wolverhampton Wanderers', 'Southampton FC', 'Queens Park Rangers', 'Hull City', 'Wigan Athletic', 'Reading FC', 'Barnsley FC', 'Luton Town',
 'Aston Villa', 'Everton FC', 'Newcastle United', 'Leeds United', 'Southampton FC', 'Crystal Palace', 'Brighton & Hove Albion', 'Burnley FC', 'Sunderland AFC', 'Blackburn Rovers','Middlesbrough FC', 'Derby County',
 'Fulham FC', 'West Bromwich Albion', 'Sheffield United', 'Nottingham Forest', 'Swansea City',  'West Bromwich Albion', 'Stoke City', 'Portsmouth FC', 'Brentford FC', 'Watford FC', 'AFC Bournemouth', 'Bradford City',
 'Cardiff City', 'Birmingham City', 'Bolton Wanderers', 'Coventry City','Swindon Town', 'Oldham Athletic', 'Charlton Athletic', 'Sheffield Wednesday'])]

# %%
#keep only where transfer_movement = in
prem_champ_df = prem_champ_df[prem_champ_df['transfer_movement'] == 'in']

# %%
#in clubname, replace ' FC' with nothing
prem_champ_df['club_name'] = prem_champ_df['club_name'].str.replace(' FC', '')

# %%
#group by club_name, year and sum fee_cleaned
prem_champ_df = prem_champ_df.groupby(['club_name', 'year']).sum('fee_cleaned').reset_index()
prem_champ_df
# Out:
#                     club_name  year    age  fee_cleaned
# 0             AFC Bournemouth  2013  865.0        4.055
# 1             AFC Bournemouth  2014  639.0        4.820
# 2             AFC Bournemouth  2015  861.0       55.110
# 3             AFC Bournemouth  2016  431.0       40.690
# 4             AFC Bournemouth  2017  382.0       34.300
# ...                       ...   ...    ...          ...
# 999   Wolverhampton Wanderers  2018  822.0      112.750
# 1000  Wolverhampton Wanderers  2019  593.0      116.700
# 1001  Wolverhampton Wanderers  2020  443.0       87.589
# 1002  Wolverhampton Wanderers  2021  529.0       37.600
# 1003  Wolverhampton Wanderers  2022  716.0      177.107
#
# [1004 rows x 4 columns]

# %%
#give me unique club names in prem_champ_df
prem_champ_df['club_name'].unique()
# Out:
# array(['AFC Bournemouth', 'Arsenal', 'Aston Villa', 'Barnsley',
#        'Birmingham City', 'Blackburn Rovers', 'Blackpool',
#        'Bolton Wanderers', 'Bradford City', 'Brentford',
#        'Brighton & Hove Albion', 'Burnley', 'Cardiff City',
#        'Charlton Athletic', 'Chelsea', 'Coventry City', 'Crystal Palace',
#        'Derby County', 'Everton', 'Fulham', 'Huddersfield Town',
#        'Hull City', 'Ipswich Town', 'Leeds United', 'Leicester City',
#        'Liverpool', 'Luton Town', 'Manchester City', 'Manchester United',
#        'Middlesbrough', 'Newcastle United', 'Norwich City',
#        'Nottingham Forest', 'Oldham Athletic', 'Portsmouth',
#        'Queens Park Rangers', 'Reading', 'Sheffield United',
#        'Sheffield Wednesday', 'Southampton', 'Stoke City',
#        'Sunderland AFC', 'Swansea City', 'Swindon Town',
#        'Tottenham Hotspur', 'Watford', 'West Bromwich Albion',
#        'West Ham United', 'Wigan Athletic', 'Wimbledon',
# ...

# %%
#remove the age column
prem_champ_df = prem_champ_df.drop(columns=['age'])

# %%
#unmelt this dataframe
prem_champ_df = prem_champ_df.pivot(index='club_name', columns='year', values='fee_cleaned').reset_index()
prem_champ_df
# Out:
# year                club_name   1992    1993    1994    1995    1996    1997  \
# 0             AFC Bournemouth    NaN     NaN     NaN     NaN     NaN     NaN
# 1                     Arsenal  4.600   1.280   7.180  18.350   6.110  22.025
# 2                 Aston Villa  3.930   4.250   7.340  11.067   8.100  10.500
# 3                    Barnsley    NaN     NaN     NaN     NaN     NaN   6.937
# 4             Birmingham City    NaN     NaN     NaN     NaN     NaN     NaN
# 5            Blackburn Rovers  9.938  11.780   9.750  16.500   0.000  10.125
# 6                   Blackpool    NaN     NaN     NaN     NaN     NaN     NaN
# 7            Bolton Wanderers    NaN     NaN     NaN   9.496     NaN  14.210
# 8               Bradford City    NaN     NaN     NaN     NaN     NaN     NaN
# 9                   Brentford    NaN     NaN     NaN     NaN     NaN     NaN
# 10     Brighton & Hove Albion    NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
#save prem champ as a csv file
prem_champ_df.to_csv('fees.csv', index=False)
